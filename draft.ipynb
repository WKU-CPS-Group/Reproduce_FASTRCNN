# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
 # Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %%
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(polar=True))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)
# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')
# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
import numpy as np 
import torch
list = [1,2,3,4]
print(list[0:2])
# Out:
# [1, 2]

# %%
import torch

x = torch.tensor([1, 2, 3, 4])
y = torch.tensor([4, 3, 2, 1])

output = torch.where(x > y)
print(output)
# Out:
# (tensor([2, 3]),)

# %%
import numpy as np

a = np.random.rand(5,4,3)
print("a =",a)

b = a[[1,2],:]
print("b =",b)
# Out:
# a = [[[0.51434545 0.79070626 0.47875034]
#   [0.3167823  0.15260659 0.67738662]
#   [0.46266272 0.76308694 0.92300036]
#   [0.91957186 0.94026913 0.70965234]]
#
#  [[0.04037599 0.34913607 0.57586502]
#   [0.97845882 0.74252994 0.60541642]
#   [0.5857055  0.80447256 0.13139027]
#   [0.8893161  0.74281275 0.36267898]]
#
#  [[0.71594261 0.30063425 0.98259575]
#   [0.35596334 0.33295973 0.34378911]
#   [0.06670484 0.29106706 0.71279768]
#   [0.70962842 0.99756354 0.92861214]]
#
#  [[0.83670324 0.98063882 0.9266936 ]
#   [0.85828911 0.394842   0.57939061]
#   [0.66620941 0.7712991  0.78798605]
#   [0.26545251 0.08559868 0.46792957]]
#
#  [[0.3361789  0.09553729 0.69633511]
#   [0.31126681 0.92745787 0.15407932]
#   [0.42535907 0.38706684 0.95796009]
#   [0.80627628 0.09782403 0.36656891]]]
# b = [[[0.04037599 0.34913607 0.57586502]
#   [0.97845882 0.74252994 0.60541642]
#   [0.5857055  0.80447256 0.13139027]
#   [0.8893161  0.74281275 0.36267898]]
#
#  [[0.71594261 0.30063425 0.98259575]
#   [0.35596334 0.33295973 0.34378911]
#   [0.06670484 0.29106706 0.71279768]
#   [0.70962842 0.99756354 0.92861214]]]
